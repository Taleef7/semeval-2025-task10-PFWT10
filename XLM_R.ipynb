# %% [markdown]
# <h3>Google Colab Setup</h3>

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# <h3>Step 2: Install and Import Libraries</h3>

# %%
# !pip install transformers datasets sklearn torch tqdm
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Collecting datasets
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import os
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import XLMRobertaTokenizer, XLMRobertaForSequenceClassification, XLMRobertaModel
from sklearn.preprocessing import MultiLabelBinarizer
import torch.nn as nn
from torch.cuda.amp import GradScaler, autocast  # For mixed precision
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# <h3>Load the XLM-R Model and Tokenizer</h3>

# %%
class XLMRWithEntityRoles(nn.Module):
    def __init__(self, pretrained_model_name='xlm-roberta-base', num_main_roles=3, num_fine_roles=22):
        super(XLMRWithEntityRoles, self).__init__()
        self.xlm_r = XLMRobertaModel.from_pretrained(pretrained_model_name)

        # Main role classification head (single-label classification)
        self.main_role_classifier = nn.Linear(self.xlm_r.config.hidden_size, num_main_roles)

        # Fine-grained role classification head (multi-label classification)
        self.fine_role_classifier = nn.Linear(self.xlm_r.config.hidden_size, num_fine_roles)

    def forward(self, input_ids, attention_mask):
        # Forward pass through XLM-R base
        outputs = self.xlm_r(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output  # Use the pooled output

        # Predict main role
        main_role_logits = self.main_role_classifier(pooled_output)

        # Predict fine-grained roles
        fine_role_logits = self.fine_role_classifier(pooled_output)

        return main_role_logits, fine_role_logits

# %%
# Load XLM-R model and tokenizer
tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base')
# Instantiate the custom model
model = XLMRWithEntityRoles(
    pretrained_model_name='xlm-roberta-base',
    num_main_roles=3,  # Protagonist, Antagonist, Innocent
    num_fine_roles=22  # Total number of fine-grained roles from taxonomy
).to(device)  # Move to GPU
print(f"Using device: {device}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Using device: cuda

# %% [markdown]
# <h3>Load One Article and Its Annotation</h3>

# %%
import os

# Function to load all articles from a given folder
def load_all_articles(lang_folder):
    """Load all articles from the language folder into a dictionary."""
    articles = {}
    for filename in os.listdir(lang_folder):
        if filename.endswith(".txt"):
            article_id = filename.split('.')[0]  # Extract article ID without .txt
            with open(os.path.join(lang_folder, filename), 'r', encoding='utf-8') as f:
                articles[article_id] = f.read()  # Store article content
    print(f"Loaded {len(articles)} articles.")
    return articles

# Function to load all annotations from the annotations file
def load_all_annotations(annotation_file):
    """Load all annotations into a dictionary grouped by article ID."""
    annotations = {}
    with open(annotation_file, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('\t')
            article_id = parts[0].split('.')[0]  # Extract article ID without .txt

            # Create a new list for the article's annotations if not already present
            if article_id not in annotations:
                annotations[article_id] = []

            # Add the annotation to the respective article's list
            annotations[article_id].append({
                'article_id': article_id,
                'entity': parts[1],
                'start': int(parts[2]),
                'end': int(parts[3]),
                'main_role': parts[4],
                'fine_roles': parts[5:]
            })
    print(f"Loaded annotations for {len(annotations)} articles.")
    return annotations

# Example usage
lang_folder = "EN/raw-documents"  # Folder containing English articles
annotation_file = "EN/annotations/subtask-1-annotations.txt"

# Load all articles and annotations
articles = load_all_articles(lang_folder)
annotations = load_all_annotations(annotation_file)

# Article ID: EN_UA_021918, Annotations: 1
# Article ID: EN_UA_027879, Annotations: 7
# Article ID: EN_UA_004343, Annotations: 2
# Article ID: EN_UA_026740, Annotations: 5
# Article ID: EN_UA_008072, Annotations: 1
# Article ID: EN_UA_100688, Annotations: 4
# Article ID: EN_UA_029155, Annotations: 5
# Article ID: EN_UA_001032, Annotations: 4
# Article ID: EN_CC_100066, Annotations: 1
# Article ID: EN_UA_103995, Annotations: 2
# Article ID: EN_UA_017831, Annotations: 6
# Article ID: EN_UA_021310, Annotations: 7
# Article ID: EN_UA_016012, Annotations: 7
# Article ID: EN_UA_104434, Annotations: 1
# Article ID: EN_UA_014829, Annotations: 5
# Article ID: EN_CC_100038, Annotations: 2
# Article ID: EN_UA_103517, Annotations: 2
# Article ID: EN_CC_100123, Annotations: 2
# Article ID: EN_UA_103025, Annotations: 2
# Article ID: EN_UA_010091, Annotations: 5
# Article ID: EN_UA_100210, Annotations: 1
# Article ID: EN_UA_100864, Annotations: 3
# Article ID: EN_CC_200021, Annotations: 4
# Article ID: EN_UA_028520, Annotations: 3
# Article ID: EN_UA_100601, Annotations: 2
# Article ID: EN_CC_100050, Annotations: 1
# Article ID: EN_CC_100003, Annotations: 2
# Article ID: EN_UA_100411, Annotations: 2
# Article ID: EN_UA_021872, Annotations: 2
# Article ID: EN_UA_021123, Annotations: 2
# Article ID: EN_UA_012234, Annotations: 2
# Article ID: EN_UA_010909, Annotations: 4
# Article ID: EN_UA_021263, Annotations: 4
# Article ID: EN_CC_100012, Annotations: 6
# Article ID: EN_UA_013727, Annotations: 7
# Article ID: EN_UA_012803, Annotations: 4
# Article ID: EN_CC_200016, Annotations: 5
# Article ID: EN_UA_104523, Annotations: 1
# Article ID: EN_UA_011260, Annotations: 7
# Article ID: EN_CC_100124, Annotations: 2
# Article ID: EN_CC_100002, Annotations: 1
# Article ID: EN_CC_200022, Annotations: 3
# Article ID: EN_UA_013257, Annotations: 5
# Article ID: EN_UA_000104, Annotations: 6
# Article ID: EN_UA_027787, Annotations: 5
# Using device: cuda

# %% [markdown]
# <h3>Marking Entity Mentions and Tokenization</h3>

# %%
def get_entity_context(article, annotation, window_size=50):
    """Extract a window of text around a single entity."""
    start = max(int(annotation['start']) - window_size, 0)
    end = min(int(annotation['end']) + window_size, len(article))
    return article[start:end]

def mark_entity_in_context(context, annotation):
    """Wrap the entity in the context window with [ENTITY] and [/ENTITY] tags."""
    entity_start = context.find(annotation['entity'])

    if entity_start == -1:
        raise ValueError(f"Entity '{annotation['entity']}' not found in the provided context.")

    # Compute the end of the entity within the context
    entity_end = entity_start + len(annotation['entity'])

    # Mark the entity in the context
    marked_context = (
        context[:entity_start] +
        f"[ENTITY]{annotation['entity']}[/ENTITY]" +
        context[entity_end:]
    )

    return marked_context


# # Example usage
# marked_content = mark_entity_in_context(article, annotations)
# print("Marked Article Content:\n", marked_content)




# def extract_context_around_entity(article, start, end, window_size=150):
#     """Extract a snippet of context around the entity mention."""
#     context_start = max(0, start - window_size)
#     context_end = min(len(article), end + window_size)
#     return article[context_start:context_end]


# def mark_entity_in_context(entity_context, entity):
#     """Wrap the specific entity mention with [ENTITY] and [/ENTITY]."""
#     return entity_context.replace(entity, f"[ENTITY]{entity}[/ENTITY]")


# def tokenize_marked_context(marked_context):
#     """Tokenize the marked context using the XLM-R tokenizer."""
#     return tokenizer(
#         marked_context,
#         padding='max_length',
#         max_length=512,
#         truncation=True,
#         return_tensors="pt"
#     )


# Tokenize the marked article
def tokenize_marked_article(marked_article):
    """Tokenize the entire marked article."""
    tokenized_output = tokenizer(
        marked_article,
        padding='max_length',
        max_length=512,
        truncation=True,
        return_tensors='pt'
    )
    return tokenized_output

# # Tokenize the marked article
# tokenized_article = tokenize_marked_article(marked_content)

# # Example output
# print("Tokenized Article:\n", tokenized_article)


# Example usage
# marked_article = mark_entities_in_article(article, annotations)
# print("Marked Article Content:\n", marked_article[:2500])  # Print first 500 chars

# # Tokenize the marked article
# tokenized_article = tokenize_article(marked_article)
# print("\nTokenized Article:\n", tokenized_article)
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Role-to-label conversion
MAIN_ROLE_MAPPING = {"Protagonist": 0, "Antagonist": 1, "Innocent": 2}

FINE_GRAINED_ROLE_LIST = [
    "Guardian", "Martyr", "Peacemaker", "Rebel", "Underdog", "Virtuous",
    "Instigator", "Conspirator", "Tyrant", "Foreign Adversary", "Traitor",
    "Spy", "Saboteur", "Corrupt", "Incompetent", "Terrorist", "Deceiver",
    "Bigot", "Forgotten", "Exploited", "Victim", "Scapegoat"
]

ROLE_MAPPING = {
    "Protagonist": ["Guardian", "Virtuous", "Peacemaker", "Underdog", "Martyr"],
    "Antagonist": ["Conspirator", "Spy", "Terrorist", "Instigator", "Tyrant", "Saboteur"],
    "Innocent": ["Victim", "Forgotten", "Exploited", "Scapegoat"]
}

def role_to_label(annotation):
    """Convert main role and fine-grained roles to label tensors."""
    # Main role label mapping
    main_role_label = MAIN_ROLE_MAPPING[annotation['main_role']]

    # Filter fine-grained roles based on the main role
    valid_roles = ROLE_MAPPING.get(annotation['main_role'], [])
    fine_role_labels = [0] * len(FINE_GRAINED_ROLE_LIST)

    for role in annotation['fine_roles']:
        if role in valid_roles:
            fine_role_labels[FINE_GRAINED_ROLE_LIST.index(role)] = 1

    return main_role_label, fine_role_labels
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from torch.utils.data import Dataset, DataLoader, random_split

class EntityRoleDataset(Dataset):
    def __init__(self, articles, annotations, window_size=50):
        """
        Initialize the dataset with all articles and their respective annotations.
        :param articles: Dictionary of article_id -> article content
        :param annotations: Dictionary of article_id -> list of annotations
        :param window_size: Size of the context window around entities.
        """
        self.articles = articles
        self.annotations = annotations
        self.window_size = window_size

        # Flatten (article_id, annotation) pairs for easy indexing
        self.data = [
            (article_id, annotation)
            for article_id, anns in annotations.items()
            for annotation in anns
        ]

    def __len__(self):
        # Number of samples = number of annotations across all articles
        return len(self.data)

    def __getitem__(self, idx):
        # Get the (article_id, annotation) pair for the current index
        article_id, annotation = self.data[idx]

        # Get the article content
        article = self.articles[article_id]

        # Get the context window around the entity
        context = get_entity_context(article, annotation, self.window_size)

        # Mark the entity within the context
        marked_context = mark_entity_in_context(context, annotation)

        # Tokenize the marked context
        tokenized_context = tokenizer(
            marked_context,
            padding='max_length',
            max_length=512,
            truncation=True,
            return_tensors='pt'
        )

        # Convert roles to labels
        main_label, fine_labels = role_to_label(annotation)

        return (
            tokenized_context['input_ids'].squeeze(0),
            tokenized_context['attention_mask'].squeeze(0),
            torch.tensor(main_label).long(),  # Tensor for main role
            torch.tensor(fine_labels).float()  # Tensor for fine-grained roles
        )
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Create Dataset and DataLoader
dataset = EntityRoleDataset(articles, annotations, window_size=50)

# Split into train and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# DataLoaders for training and validation
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False)

print(f"Training examples: {len(train_dataset)}, Validation examples: {len(val_dataset)}")
print(f"Using device: {device}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-16580658d20c> in <cell line: 2>()
#       1 # Create Dataset and DataLoader
# ----> 2 dataset = EntityRoleDataset(articles, annotations, window_size=50)
#       3
#       4 # Split into train and validation sets
#       5 train_size = int(0.8 * len(dataset))
#
# <ipython-input-17-ab4874d2b571> in __init__(self, articles, annotations, window_size)
#      16         self.data = [
#      17             (article_id, annotation)
# ---> 18             for article_id, anns in annotations.items()
#      19             for annotation in anns
#      20         ]
#
# AttributeError: 'list' object has no attribute 'items'

# %%
import torch.optim as optim
from tqdm import tqdm  # For progress bar

# Optimizer
optimizer = optim.AdamW(model.parameters(), lr=2e-5)  # Use AdamW for fine-tuning

# Loss functions with weighting
main_role_loss_fn = nn.CrossEntropyLoss(weight=torch.tensor([2.0, 1.0, 3.0]).to(device))
fine_grained_loss_fn = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([1.5]).to(device))

def train_model(model, train_loader, val_loader, epochs=3, log_interval=10):
    """Train the model and log progress."""
    model.train()  # Set model to training mode

    for epoch in range(epochs):
        total_loss = 0
        print(f"Epoch {epoch + 1}/{epochs}:")

        # Create a progress bar for the epoch
        progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f"Epoch {epoch + 1}")

        for batch_idx, (input_ids, attention_mask, main_label, fine_labels) in progress_bar:
            # Move data to device (GPU or CPU)
            input_ids, attention_mask = input_ids.to(device), attention_mask.to(device)
            main_label = main_label.to(device)
            fine_labels = fine_labels.to(device, dtype=torch.float)

            # Forward pass
            optimizer.zero_grad()
            main_role_logits, fine_role_logits = model(input_ids, attention_mask)

            # Compute losses
            main_loss = main_role_loss_fn(main_role_logits, main_label)
            fine_loss = fine_grained_loss_fn(fine_role_logits, fine_labels)
            loss = main_loss + 0.5 * fine_loss  # Optional: Weighted loss

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # Log progress every few batches
            if batch_idx % log_interval == 0:
                progress_bar.set_postfix({"Batch Loss": loss.item()})

        print(f"Epoch {epoch + 1}/{epochs}, Avg Loss: {total_loss / len(train_loader):.4f}")

        # Perform validation at the end of each epoch
        validate_model(model, val_loader)

def validate_model(model, val_loader):
    """Validate the model."""
    model.eval()  # Set model to evaluation mode
    val_loss = 0

    with torch.no_grad():
        for input_ids, attention_mask, main_label, fine_labels in val_loader:
            input_ids, attention_mask = input_ids.to(device), attention_mask.to(device)
            main_label = main_label.to(device)
            fine_labels = fine_labels.to(device, dtype=torch.float)

            # Forward pass
            main_role_logits, fine_role_logits = model(input_ids, attention_mask)

            # Compute validation losses
            main_loss = main_role_loss_fn(main_role_logits, main_label)
            fine_loss = fine_grained_loss_fn(fine_role_logits, fine_labels)
            val_loss += main_loss.item() + fine_loss.item()

    print(f"Validation Loss: {val_loss / len(val_loader):.4f}")
    model.train()  # Switch back to training mode

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Start training the model
train_model(model, train_loader, val_loader, epochs=3)
# Out:
# Epoch 1/3:
# Epoch 1: 100%|██████████| 166/166 [00:44<00:00,  3.69it/s, Batch Loss=1.77]
# Epoch 1/3, Avg Loss: 1.1059
# Validation Loss: 1.0308
# Epoch 2/3:
# Epoch 2: 100%|██████████| 166/166 [00:46<00:00,  3.60it/s, Batch Loss=1.62]
# Epoch 2/3, Avg Loss: 1.0952
# Validation Loss: 1.0569
# Epoch 3/3:
# Epoch 3: 100%|██████████| 166/166 [00:46<00:00,  3.58it/s, Batch Loss=1.79]
# Epoch 3/3, Avg Loss: 1.1091
# Validation Loss: 1.0876

# %% [markdown]
# <h3>Save model</h3>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to save the model (in Colab or Google Drive)
MODEL_PATH = '/content/drive/MyDrive/xlm_model/saved_model.pth'  # Or '/content/saved_model.pth'

# Save the model's state_dict
torch.save(model.state_dict(), MODEL_PATH)
print(f"Model saved to {MODEL_PATH}")
# Out:
# Model saved to /content/drive/MyDrive/xlm_model/saved_model.pth

# %%
# Save the entire model (not just state_dict)
torch.save(model, MODEL_PATH)

# %% [markdown]
# <h3>Load Model</h3>

# %%
# Load the entire model
model = torch.load(MODEL_PATH)
model.to(device)  # Ensure model is on the correct device

# %% [markdown]
# <h3>Predict</h3>

# %%
ROLE_MAPPING = {
    "Protagonist": ["Guardian", "Virtuous", "Peacemaker", "Underdog", "Martyr"],
    "Antagonist": ["Conspirator", "Spy", "Terrorist", "Instigator", "Tyrant", "Saboteur"],
    "Innocent": ["Victim", "Forgotten", "Exploited", "Scapegoat"]
}


def predict_for_multiple_articles(model, articles_annotations, window_size=50):
    """Predict roles for entities across multiple articles."""
    model.eval()  # Set model to evaluation mode
    all_predictions = []

    with torch.no_grad():
        for article_id, (article, annotations) in articles_annotations.items():
            article_predictions = []

            for annotation in annotations:
                # Extract context window around the entity
                context = get_entity_context(article, annotation, window_size)

                # Mark the entity in the context
                marked_context = mark_entity_in_context(context, annotation)

                # Tokenize the marked context
                tokenized_context = tokenizer(
                    marked_context,
                    padding='max_length',
                    max_length=512,
                    truncation=True,
                    return_tensors='pt'
                ).to(device)  # Send to the correct device

                # Forward pass to get logits
                main_role_logits, fine_role_logits = model(
                    tokenized_context['input_ids'],
                    tokenized_context['attention_mask']
                )

                # Predict main role using softmax
                main_role_probs = torch.softmax(main_role_logits, dim=1)
                main_role_pred = torch.argmax(main_role_probs, dim=1).item()
                main_role_str = decode_main_role(main_role_pred)

                # Predict fine-grained roles using sigmoid
                fine_role_probs = torch.sigmoid(fine_role_logits).squeeze(0)
                print(f"Fine-Grained Role Probabilities: {fine_role_probs.tolist()}")
                role_threshold = fine_role_probs.mean() + fine_role_probs.std()
                fine_role_pred = (fine_role_probs > role_threshold).nonzero(as_tuple=True)[0]


                # Filter fine-grained roles to match the main role
                valid_roles = ROLE_MAPPING.get(main_role_str, [])
                print(f"Valid Roles for {main_role_str}: {valid_roles}")
                print(f"Predicted Fine Roles: {[FINE_GRAINED_ROLE_LIST[i] for i in fine_role_pred]}")

                filtered_fine_roles = [
                    FINE_GRAINED_ROLE_LIST[i] for i in fine_role_pred
                    if FINE_GRAINED_ROLE_LIST[i] in valid_roles
                ]

                # Collect predictions for the entity
                article_predictions.append({
                    'entity': annotation['entity'],
                    'main_role': main_role_str,
                    'fine_roles': filtered_fine_roles
                })

            # Store predictions for this article
            all_predictions.append({
                'article_id': article_id,
                'predictions': article_predictions
            })

    return all_predictions


# Helper function to decode the main role ID back to a string
def decode_main_role(main_role_id):
    MAIN_ROLE_MAPPING = {0: "Protagonist", 1: "Antagonist", 2: "Innocent"}
    return MAIN_ROLE_MAPPING.get(main_role_id, "Unknown")


def exact_match_ratio_for_multiple_articles(all_predictions, articles_annotations):
    """Calculate the exact match ratio across multiple articles."""
    correct = 0
    total = 0

    # Iterate through predictions and annotations using indices
    for i in range(len(all_predictions)):
        article_pred = all_predictions[i]
        annotations = articles_annotations[i]  # Get annotations directly

        pred_entities = article_pred['predictions']

        # Ensure predictions and annotations have the same length
        min_len = min(len(pred_entities), len(annotations))

        for j in range(min_len):
            pred = pred_entities[j]
            ann = annotations[j]

            # Check if main role and fine-grained roles match exactly
            if (pred['main_role'] == ann['main_role'] and
                    set(pred['fine_roles']) == set(ann['fine_roles'])):
                correct += 1
            total += 1

    return correct / total if total > 0 else 0.0

# %%
import os

# Function to load an article given its ID and folder path
def load_article(article_id, lang_folder):
    article_path = os.path.join(lang_folder, f"{article_id}")
    with open(article_path, 'r', encoding='utf-8') as f:
        article = f.read()
    return article

# Function to load all annotations from the annotation file
def load_all_annotations(annotation_file):
    annotations_dict = {}

    with open(annotation_file, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('\t')
            article_id = parts[0]  # Article ID

            # Structure the annotation
            annotation = {
                'entity': parts[1],
                'start': int(parts[2]),
                'end': int(parts[3]),
                'main_role': parts[4],
                'fine_roles': parts[5:]
            }

            # Collect annotations for each article in a list
            if article_id not in annotations_dict:
                annotations_dict[article_id] = []
            annotations_dict[article_id].append(annotation)

    return annotations_dict

# Function to create the `articles_annotations` dictionary
def load_articles_annotations(lang_folder, annotation_file):
    articles_annotations = {}

    # Load all annotations first
    annotations_dict = load_all_annotations(annotation_file)

    # Loop through the articles based on available annotation IDs
    for article_id in annotations_dict.keys():
        article_text = load_article(article_id, lang_folder)
        annotations = annotations_dict[article_id]

        # Store the article text and its annotations as a tuple
        articles_annotations[article_id] = (article_text, annotations)

    return articles_annotations

# Example Usage
lang_folder = "EN/raw-documents"  # Folder containing English articles
annotation_file = "EN/annotations/subtask-1-annotations.txt"

# Load all articles and their annotations
articles_annotations = load_articles_annotations(lang_folder, annotation_file)

# Verify the structure
for article_id, (article_text, annotations) in articles_annotations.items():
    print(f"Article ID: {article_id}")
    print(f"Article Content (First 100 chars): {article_text[:100]}")
    print(f"Annotations: {annotations}\n")
# Out:
# Article ID: EN_UA_103861.txt
# Article Content (First 100 chars): The World Needs Peacemaker Trump Again
#
#  by Jeff Crouere, The Liberty Daily:
#
# The world is in total
# Annotations: [{'entity': 'Chinese', 'start': 791, 'end': 797, 'main_role': 'Antagonist', 'fine_roles': ['Spy']}, {'entity': 'China', 'start': 1516, 'end': 1520, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Hamas', 'start': 2121, 'end': 2125, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Donald Trump', 'start': 4909, 'end': 4920, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker', 'Guardian']}]
#
# Article ID: EN_UA_021270.txt
# Article Content (First 100 chars): Ukraine's Fate Will Be Decided In Coming Year, Top Zelensky Aide Admits
#
#  Ukraine's Fate Will Be De
# Annotations: [{'entity': 'Yermak', 'start': 667, 'end': 672, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Zelensky', 'start': 846, 'end': 853, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Zelensky admin', 'start': 1400, 'end': 1413, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Yermak', 'start': 1900, 'end': 1905, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': "Zelensky's", 'start': 2104, 'end': 2113, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}]
#
# Article ID: EN_UA_103403.txt
# Article Content (First 100 chars): Russia Stages Major Airstrike on Ukraine; One Missile Enters Polish Airspace
#
#  KYIV—Russia struck c
# Annotations: [{'entity': 'Moscow', 'start': 2007, 'end': 2012, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_027676.txt
# Article Content (First 100 chars): Nato in talks to deploy more nuclear weapons amid the growing threat posed by Russia and China - as
# Annotations: [{'entity': 'Nato', 'start': 218, 'end': 221, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Russia', 'start': 296, 'end': 301, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'China', 'start': 307, 'end': 311, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Putin', 'start': 353, 'end': 357, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Kyiv', 'start': 374, 'end': 377, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Putin', 'start': 1064, 'end': 1068, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'China', 'start': 2348, 'end': 2352, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'North Korea', 'start': 2358, 'end': 2368, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'the US', 'start': 2648, 'end': 2653, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_017310.txt
# Article Content (First 100 chars): Jake Sullivan hints US won’t replenish controversial cluster munitions to Ukraine
#
#  The Biden admin
# Annotations: [{'entity': 'US', 'start': 909, 'end': 910, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Ukraine', 'start': 924, 'end': 930, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}]
#
# Article ID: EN_CC_100005.txt
# Article Content (First 100 chars): Climate Crazies Fail in Attempt to Vandalize Another Classic Work of Art
#
#  Another of the world’s m
# Annotations: [{'entity': 'Stopp Oljeletinga', 'start': 1700, 'end': 1716, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'COP27', 'start': 3657, 'end': 3661, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}]
#
# Article ID: EN_UA_008586.txt
# Article Content (First 100 chars): The Situation in the Ukraine Is an Historical Event of Immense Magnitude
#
#  by Philip Giraldi, The U
# Annotations: [{'entity': 'Washington', 'start': 949, 'end': 958, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Brussels', 'start': 964, 'end': 971, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'US', 'start': 2207, 'end': 2208, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_UA_014637.txt
# Article Content (First 100 chars): Putin’s masses of HIV-positive prisoners choosing to go to meat-grinder frontline rather than rot in
# Annotations: [{'entity': 'Wagner Group', 'start': 539, 'end': 550, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'Russia', 'start': 2461, 'end': 2466, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Yevgeny Prigozhin', 'start': 3512, 'end': 3528, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}]
#
# Article ID: EN_UA_019640.txt
# Article Content (First 100 chars): After North Korea’s Kim Jong Un, Putin and Xi to meet in Beijing in October, says Kremlin
#
#  Russian
# Annotations: [{'entity': 'Russia', 'start': 435, 'end': 440, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'China', 'start': 446, 'end': 450, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'West', 'start': 497, 'end': 500, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'International Criminal Court', 'start': 845, 'end': 872, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Russia', 'start': 1099, 'end': 1104, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'China', 'start': 1883, 'end': 1887, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Russia', 'start': 1941, 'end': 1946, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Russia', 'start': 2202, 'end': 2207, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_022051.txt
# Article Content (First 100 chars): “A Declaration of War”: UK Plans To Put British Troops In Ukraine
#
#  by Mac Slavo, SHTF Plan:
#
# Forme
# Annotations: [{'entity': 'United Kingdom', 'start': 159, 'end': 172, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'London', 'start': 368, 'end': 373, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Kiev', 'start': 379, 'end': 382, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'UK', 'start': 1781, 'end': 1782, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}]
#
# Article ID: EN_UA_004616.txt
# Article Content (First 100 chars): No one can predict war's length: Zelenskiy
#
#  Although Ukrainians are doing everything they can to d
# Annotations: [{'entity': 'Ukrainians', 'start': 55, 'end': 64, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': 'Russians', 'start': 113, 'end': 120, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'European countries', 'start': 414, 'end': 431, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Ukraine', 'start': 820, 'end': 826, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}]
#
# Article ID: EN_UA_025165.txt
# Article Content (First 100 chars): Zelensky Says US Politicians ‘Don’t Care About Ukraine’
#
#  President Volodymyr Zelensky has accused
# Annotations: [{'entity': 'US politicians', 'start': 100, 'end': 113, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': 'Kiev', 'start': 1592, 'end': 1595, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': 'the West', 'start': 2668, 'end': 2675, 'main_role': 'Antagonist', 'fine_roles': ['Instigator', 'Foreign Adversary']}]
#
# Article ID: EN_UA_024321.txt
# Article Content (First 100 chars): Molotov Cocktail Attack On Russian Embassy In Moldova On Last Day Of Election
#
#  Molotov Cocktail At
# Annotations: [{'entity': 'Yulia Navalnaya', 'start': 235, 'end': 249, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}, {'entity': 'Moscow', 'start': 1667, 'end': 1672, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Moscow', 'start': 2297, 'end': 2302, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Russian diplomats', 'start': 2401, 'end': 2417, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_000923.txt
# Article Content (First 100 chars): Boris Johnson demands Putin ‘steps back from the brink’ and says Russian invasion of Ukraine will be
# Annotations: [{'entity': 'Boris Johnson', 'start': 124, 'end': 136, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Putin', 'start': 148, 'end': 152, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Russia', 'start': 501, 'end': 506, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Germany', 'start': 1278, 'end': 1284, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'EU', 'start': 1466, 'end': 1467, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Britain', 'start': 1510, 'end': 1516, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'UK', 'start': 1581, 'end': 1582, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Brexit Britain', 'start': 2047, 'end': 2060, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}]
#
# Article ID: EN_CC_100095.txt
# Article Content (First 100 chars): Climate Change Hoaxer Greta Thunberg Charged for Disobeying Law Enforcement in Sweden’s Climate Prot
# Annotations: [{'entity': 'Greta Thunberg', 'start': 269, 'end': 282, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Irma Kjellström', 'start': 1297, 'end': 1311, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}, {'entity': 'Greta Thunberg', 'start': 1691, 'end': 1704, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_CC_100106.txt
# Article Content (First 100 chars): WATCH: Junk Scientist and Serial Liar Al Gore Makes Absurd Global Warming Prediction “Once We Get to
# Annotations: [{'entity': 'Al Gore', 'start': 140, 'end': 146, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Al Gore', 'start': 488, 'end': 494, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Al Gore', 'start': 1386, 'end': 1392, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_014014.txt
# Article Content (First 100 chars): End overseas trade settlement in dollar, use your own currency: Brazil President Lula to BRICS natio
# Annotations: [{'entity': 'Lula', 'start': 644, 'end': 647, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}, {'entity': 'IMF', 'start': 2372, 'end': 2374, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Argentina', 'start': 2394, 'end': 2402, 'main_role': 'Innocent', 'fine_roles': ['Exploited']}, {'entity': 'Brazil', 'start': 2430, 'end': 2435, 'main_role': 'Innocent', 'fine_roles': ['Exploited']}]
#
# Article ID: EN_UA_026697.txt
# Article Content (First 100 chars): The Eurocrats Fear That Fico's Attempted Assassination Will Influence Next Month's Elections
#
#  The
# Annotations: [{'entity': 'Slovak Prime Minister Robert Fico', 'start': 631, 'end': 663, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Victor Orban', 'start': 1269, 'end': 1280, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'von der Leyen', 'start': 1594, 'end': 1606, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'Jourova', 'start': 1612, 'end': 1618, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}]
#
# Article ID: EN_UA_101067.txt
# Article Content (First 100 chars): First war of TikTok era sees tragedy, humor and deceit
#
#  eart-rending videos of artillery strikes a
# Annotations: [{'entity': 'RIA Novosti', 'start': 3825, 'end': 3835, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_UA_002531.txt
# Article Content (First 100 chars): Kyiv's Mayor Says He's 'Ready to Fight' as Russians Continue Kidnappings
#
#  Kyiv Mayor Vitali Klitsc
# Annotations: [{'entity': 'Kyiv Mayor Vitali Klitschko', 'start': 76, 'end': 102, 'main_role': 'Protagonist', 'fine_roles': ['Rebel', 'Martyr']}, {'entity': 'Russian military', 'start': 219, 'end': 234, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Russian forces', 'start': 258, 'end': 271, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Klitschko', 'start': 456, 'end': 464, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Klitschko', 'start': 717, 'end': 725, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Mayor Matveev Sergeevich', 'start': 1279, 'end': 1302, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Mayor Ivan Fedorov', 'start': 1346, 'end': 1363, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Russian invaders', 'start': 1616, 'end': 1631, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Russians', 'start': 1917, 'end': 1924, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}]
#
# Article ID: EN_UA_103732.txt
# Article Content (First 100 chars): Zelensky Exposed: Former Advisor Reveals How Ukrainian President Thinks He's Omnipotent
#
#  Zelensky
# Annotations: [{'entity': 'Zelensky', 'start': 274, 'end': 281, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_002668.txt
# Article Content (First 100 chars): Putin may ABANDON siege of Kyiv and try to blitz other cities into submission after losing thousands
# Annotations: [{'entity': 'Vlad Putin', 'start': 230, 'end': 239, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Ukrainians', 'start': 853, 'end': 862, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Putin', 'start': 1269, 'end': 1273, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Russia', 'start': 1589, 'end': 1594, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Putin', 'start': 1750, 'end': 1754, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_025652.txt
# Article Content (First 100 chars): Russia says there is ‘no basis’ for arms control, strategic stability dialogue with US
#
#  Russia on
# Annotations: [{'entity': 'the West', 'start': 858, 'end': 865, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'US-', 'start': 1095, 'end': 1097, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator', 'Deceiver']}, {'entity': 'West', 'start': 1114, 'end': 1117, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator', 'Deceiver']}]
#
# Article ID: EN_UA_014413.txt
# Article Content (First 100 chars): Vladimir Putin’s cyber warfare chief sent sex toys after his email is hacked
#
#  A top Russian milita
# Annotations: [{'entity': 'GRU', 'start': 1660, 'end': 1662, 'main_role': 'Antagonist', 'fine_roles': ['Spy']}]
#
# Article ID: EN_CC_100076.txt
# Article Content (First 100 chars): Reuters Joins BBC in Failed ‘Fact Check’ of Daily Sceptic Arctic Sea Ice Story
#
#  Another day, anoth
# Annotations: [{'entity': 'Reuters', 'start': 129, 'end': 135, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Daily Sceptic', 'start': 176, 'end': 188, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}, {'entity': 'Walt Meier', 'start': 843, 'end': 852, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Daily Sceptic', 'start': 1307, 'end': 1319, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_013710.txt
# Article Content (First 100 chars): Operation Babylift and the Hypocrisy of the International Criminal Court
#
#  by Kurt Nimmo, Kurt Nimm
# Annotations: [{'entity': 'ICC', 'start': 207, 'end': 209, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'Max Boot', 'start': 314, 'end': 321, 'main_role': 'Antagonist', 'fine_roles': ['Bigot', 'Deceiver']}, {'entity': 'Putin', 'start': 399, 'end': 403, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Iraq', 'start': 625, 'end': 628, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'ICC', 'start': 738, 'end': 740, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Vietnamese children', 'start': 1049, 'end': 1067, 'main_role': 'Innocent', 'fine_roles': ['Exploited']}]
#
# Article ID: EN_UA_024847.txt
# Article Content (First 100 chars): Polish Foreign Minister Reveals Biden Knew About Nord Stream Explosion in Advance
#
#  The United Stat
# Annotations: [{'entity': 'United States', 'start': 89, 'end': 101, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Conspirator']}, {'entity': 'Washington', 'start': 439, 'end': 448, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Joe Biden', 'start': 622, 'end': 630, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Seymour Hersh', 'start': 1351, 'end': 1363, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Ukraine', 'start': 2559, 'end': 2565, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Instigator']}, {'entity': 'Russia', 'start': 2674, 'end': 2679, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}, {'entity': 'Ukraine', 'start': 2800, 'end': 2806, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Conspirator']}]
#
# Article ID: EN_UA_100587.txt
# Article Content (First 100 chars): Almost 300 kids snatched from Ukrainian city in ONE month to be ‘zombified’ by Putin’s thugs at Russ
# Annotations: [{'entity': 'RUSSIA', 'start': 122, 'end': 127, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Vladimir Putin', 'start': 741, 'end': 754, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Ukrainians', 'start': 2652, 'end': 2661, 'main_role': 'Innocent', 'fine_roles': ['Exploited', 'Victim']}]
#
# Article ID: EN_CC_100136.txt
# Article Content (First 100 chars): Climate Science Denial Group GWPF Admits It Used False Temperature Graph
#
#  The climate science deny
# Annotations: [{'entity': 'Global Warming Policy Foundation', 'start': 114, 'end': 145, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Lord Lawson', 'start': 221, 'end': 231, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent', 'Deceiver']}, {'entity': 'Daily Stormer', 'start': 1775, 'end': 1787, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}]
#
# Article ID: EN_UA_028103.txt
# Article Content (First 100 chars): Russian Plot To Assassinate CEO Of German Arms Giant Dismissed As 'Fake' Intel Story By Kremlin
#
#  R
# Annotations: [{'entity': 'Russian intelligence', 'start': 296, 'end': 315, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Armin Papperger', 'start': 344, 'end': 358, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Russian government', 'start': 811, 'end': 828, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Conspirator']}, {'entity': 'Moscow', 'start': 2787, 'end': 2792, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_015443.txt
# Article Content (First 100 chars): Ukraine War: Kyiv’s allies fear military support will dry up in US election year
#
#  Ukraine’s Wester
# Annotations: [{'entity': 'Ukraine', 'start': 732, 'end': 738, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}]
#
# Article ID: EN_CC_100047.txt
# Article Content (First 100 chars): Biden Has Omnibus Bill, Packed With Climate Change Policies, Flown By Private Jet to Virgin Islands
# Annotations: [{'entity': 'John Kerry', 'start': 437, 'end': 446, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Democrats', 'start': 905, 'end': 913, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}]
#
# Article ID: EN_CC_100004.txt
# Article Content (First 100 chars): A Tesla Owner Just Exposed A Sick Secret About Electric Cars…
#
#  A Tesla Owner Just Exposed A Sick S
# Annotations: [{'entity': 'Al Gore', 'start': 328, 'end': 334, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'China', 'start': 565, 'end': 569, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'ete Buttigieg', 'start': 2715, 'end': 2727, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_UA_022016.txt
# Article Content (First 100 chars): "Russia does not feel threatened": Estonian Prime Minister calls for long-range missiles to be trans
# Annotations: [{'entity': 'Russia', 'start': 132, 'end': 137, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Kyiv', 'start': 406, 'end': 409, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': 'Estonian government', 'start': 694, 'end': 712, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Ukraine', 'start': 1677, 'end': 1683, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Ukraine', 'start': 1978, 'end': 1984, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}]
#
# Article ID: EN_CC_100091.txt
# Article Content (First 100 chars): FACT CHECK: Did Greta Thunberg Say Saving The Banks Would Save The World?
#
#  FACT CHECK: Did Greta T
# Annotations: [{'entity': 'Greta Thunberg', 'start': 216, 'end': 229, 'main_role': 'Innocent', 'fine_roles': ['Exploited']}]
#
# Article ID: EN_UA_023008.txt
# Article Content (First 100 chars): What Everyone Is Missing About the Putin/Carlson Talk
#
#  by Tom Luongo, Tom Luongo:
#
# “The Vorlons sa
# Annotations: [{'entity': 'Davos/UK dominated media', 'start': 372, 'end': 395, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Carlson', 'start': 2801, 'end': 2807, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}, {'entity': 'Hillary Clinton', 'start': 2822, 'end': 2836, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_UA_002416.txt
# Article Content (First 100 chars): Facebook now warns users NOT to ‘call for Putin assassination’ after controversial rule change
#
#  Fa
# Annotations: [{'entity': 'Meta', 'start': 275, 'end': 278, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': "Meta's", 'start': 1398, 'end': 1403, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Clegg', 'start': 1866, 'end': 1870, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'Russia', 'start': 2912, 'end': 2917, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_UA_103011.txt
# Article Content (First 100 chars): Energy giant Centrica is prepared to do the right thing, small beer though it looks
#
#  Energy giant
# Annotations: [{'entity': 'Shell', 'start': 749, 'end': 753, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'BP', 'start': 759, 'end': 760, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'Russians', 'start': 988, 'end': 995, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_010735.txt
# Article Content (First 100 chars): Russia's Infrastructure Attacks Could Impact Ukraine's Neighbors: Official
#
#  Russia's latest attack
# Annotations: [{'entity': "Russia's", 'start': 78, 'end': 85, 'main_role': 'Antagonist', 'fine_roles': ['Instigator', 'Foreign Adversary']}, {'entity': 'Russian military', 'start': 475, 'end': 490, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Russia', 'start': 1676, 'end': 1681, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}]
#
# Article ID: EN_UA_025764.txt
# Article Content (First 100 chars): Nuclear War Back on the Table; I’m Loading Up on SILVER!!
#
#  We proudly RE-POST this publication, or
# Annotations: [{'entity': 'Stanislav Petrov', 'start': 1794, 'end': 1809, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Ukraine', 'start': 1918, 'end': 1924, 'main_role': 'Innocent', 'fine_roles': ['Exploited']}, {'entity': 'France', 'start': 1927, 'end': 1932, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Biden', 'start': 2128, 'end': 2132, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Washington', 'start': 2519, 'end': 2528, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Washington', 'start': 2592, 'end': 2601, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Russia', 'start': 2876, 'end': 2881, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_012611.txt
# Article Content (First 100 chars): Russia wants UN probe into Nord Stream gas pipelines explosions
#
#  Moscow: Russia will ask the UN Se
# Annotations: [{'entity': 'Russia', 'start': 75, 'end': 80, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'US', 'start': 225, 'end': 226, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Norway', 'start': 1493, 'end': 1498, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_102990.txt
# Article Content (First 100 chars): At Last, a Credible Explanation of How Kakhovka Dam Was Blown Up
#
#  by Eric Zuesse, The Duran:
#
# Thou
# Annotations: [{'entity': 'Ukrainian Government', 'start': 759, 'end': 778, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Russia', 'start': 955, 'end': 960, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}]
#
# Article ID: EN_UA_024628.txt
# Article Content (First 100 chars): Washington will not let Ukraine fail, US defence chief vows
#
#  RAMSTEIN AIR BASE - Defense Secretary
# Annotations: [{'entity': 'United States', 'start': 140, 'end': 152, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Ukraine', 'start': 167, 'end': 173, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': 'Russia', 'start': 196, 'end': 201, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Ukraine', 'start': 731, 'end': 737, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}, {'entity': 'Ukraine', 'start': 2062, 'end': 2068, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Moscow', 'start': 2361, 'end': 2366, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Berlin', 'start': 2746, 'end': 2751, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Germany', 'start': 2929, 'end': 2935, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Washington', 'start': 2998, 'end': 3007, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_013617.txt
# Article Content (First 100 chars): Filling the Blank Spots in Our National History
#
#  by Ron Unz, The Unz Review:
#
# The Truth About the
# Annotations: [{'entity': 'President Vladimir Putin', 'start': 929, 'end': 952, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Putin', 'start': 1125, 'end': 1129, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'ICC', 'start': 1361, 'end': 1363, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'American Secretary of State Madeleine Albright', 'start': 1400, 'end': 1445, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'John Bolton', 'start': 1646, 'end': 1656, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Russia', 'start': 2414, 'end': 2419, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'China', 'start': 2425, 'end': 2429, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Saudi Arabia', 'start': 2682, 'end': 2693, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Iran', 'start': 2699, 'end': 2702, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'America', 'start': 3039, 'end': 3045, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Western allies', 'start': 3055, 'end': 3068, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_UA_024050.txt
# Article Content (First 100 chars): How NATO powers are using the U.K.’s World War I model to lure Russia into the next big global war
#
# Annotations: [{'entity': 'U.K', 'start': 185, 'end': 187, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'German generals', 'start': 514, 'end': 528, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'German generals', 'start': 981, 'end': 995, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'German Army', 'start': 1230, 'end': 1240, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Russia', 'start': 1381, 'end': 1386, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Germany', 'start': 2178, 'end': 2184, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': 'Ukraine', 'start': 2252, 'end': 2258, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'France', 'start': 2529, 'end': 2534, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Poland', 'start': 2540, 'end': 2545, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Weimar Triangle', 'start': 2902, 'end': 2916, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_016466.txt
# Article Content (First 100 chars): The Threat from the Kremlin’s Foolish, Never-ending, “limited military operation” in Ukraine continu
# Annotations: [{'entity': 'Putin', 'start': 114, 'end': 118, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}, {'entity': 'Russia', 'start': 2121, 'end': 2126, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'the West', 'start': 2225, 'end': 2232, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_023816.txt
# Article Content (First 100 chars): NATO Troops Are Operating In Ukraine Disguised As Mercenaries, Russian General Claims
#
#  NATO Troops
# Annotations: [{'entity': 'NATO', 'start': 89, 'end': 92, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Western countries', 'start': 1664, 'end': 1680, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Washington', 'start': 1790, 'end': 1799, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Brussels', 'start': 1805, 'end': 1812, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'United States', 'start': 1990, 'end': 2002, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_026142.txt
# Article Content (First 100 chars): Oppose imperialist War! SEP/IYSSE public meeting in Sri Lanka
#
#  The Socialist Equality Party (SEP)
# Annotations: [{'entity': 'Israel', 'start': 535, 'end': 540, 'main_role': 'Antagonist', 'fine_roles': ['Instigator', 'Tyrant']}, {'entity': 'Palestinians', 'start': 569, 'end': 580, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'US-', 'start': 590, 'end': 592, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Iran', 'start': 616, 'end': 619, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Biden', 'start': 1284, 'end': 1288, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Sunak', 'start': 1291, 'end': 1295, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Macron', 'start': 1298, 'end': 1303, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Scholz', 'start': 1309, 'end': 1314, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Julian Assange', 'start': 1738, 'end': 1751, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Bogdan Syrotiuk', 'start': 1834, 'end': 1848, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}, {'entity': 'Zelensky', 'start': 1927, 'end': 1934, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Bogdan', 'start': 2024, 'end': 2029, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Zionist', 'start': 2564, 'end': 2570, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}, {'entity': 'working class', 'start': 2802, 'end': 2814, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}]
#
# Article ID: EN_UA_002991.txt
# Article Content (First 100 chars): Russian On-air Protester Fined, Faces Possible Prison Term
#
#  NEW YORK—An employee of Russian state
# Annotations: [{'entity': 'Marina Ovsyannikova', 'start': 274, 'end': 292, 'main_role': 'Protagonist', 'fine_roles': ['Rebel', 'Martyr']}, {'entity': 'Russia', 'start': 799, 'end': 804, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Vladimir Putin', 'start': 847, 'end': 860, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_UA_022339.txt
# Article Content (First 100 chars): "Aren't They Fools?": Putin Says Ukrainian Statehood Risks 'Irreparable Blow' If War Continues
#
#  "A
# Annotations: [{'entity': "Ukraine's military", 'start': 757, 'end': 774, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Russian civilians', 'start': 1455, 'end': 1471, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Zelensky', 'start': 2316, 'end': 2323, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': 'Western powers', 'start': 2361, 'end': 2374, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Prime Minister of Britain Mr. [Boris] Johnson', 'start': 2592, 'end': 2636, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'China', 'start': 3147, 'end': 3151, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}]
#
# Article ID: EN_UA_026036.txt
# Article Content (First 100 chars): Russia pounds 30 towns and villages in Ukraine’s Kharkiv region
#
#  KHARKIV - Russia pounded over 30
# Annotations: [{'entity': 'Russia', 'start': 77, 'end': 82, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_029053.txt
# Article Content (First 100 chars): British colonel: Ukrainian operation in Kursk region humiliated Putin and showed cowardice of allies
# Annotations: [{'entity': 'Putin', 'start': 178, 'end': 182, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Joe Biden', 'start': 871, 'end': 879, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Keir Starmer', 'start': 908, 'end': 919, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Volodymyr Zelenskyy', 'start': 962, 'end': 980, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': "Russia's", 'start': 1617, 'end': 1624, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Ukraine', 'start': 1649, 'end': 1655, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Putin', 'start': 2795, 'end': 2799, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Biden', 'start': 2908, 'end': 2912, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'Ayatollah Khamenei', 'start': 2994, 'end': 3011, 'main_role': 'Antagonist', 'fine_roles': ['Instigator', 'Tyrant']}, {'entity': 'Putin', 'start': 3107, 'end': 3111, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'the West', 'start': 3204, 'end': 3211, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_015962.txt
# Article Content (First 100 chars): Dramatic moment anti-Putin troops ‘INVADE Russia in tank and drone assault across border before seiz
# Annotations: [{'entity': 'Vyacheslav Gladkov', 'start': 495, 'end': 512, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': "Putin's Russia", 'start': 1430, 'end': 1443, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_CC_100036.txt
# Article Content (First 100 chars): FACT CHECK: Is NASA Planning To Blast Ice Particles Into The Atmosphere To Fight Climate Change?
#
#
# Annotations: [{'entity': 'NASA)', 'start': 283, 'end': 287, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_104876.txt
# Article Content (First 100 chars): Putin honours army unit blamed for Bucha massacre with award for ‘heroism and bravery’
#
#  VLADIMIR P
# Annotations: [{'entity': 'VLADIMIR Putin', 'start': 90, 'end': 103, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'President Volodymyr Zelensky', 'start': 2305, 'end': 2332, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_013344.txt
# Article Content (First 100 chars): I was a KGB spy along side Putin and he IS using body doubles – these simple signs are a dead giveaw
# Annotations: [{'entity': 'Vladimir Putin', 'start': 172, 'end': 185, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Zhirnov', 'start': 1329, 'end': 1335, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}]
#
# Article ID: EN_UA_104859.txt
# Article Content (First 100 chars): A Former Ukrainian MP Blew The Whistle On Burisma's Connections To Terrorism
#
#  A Former Ukrainian M
# Annotations: [{'entity': 'GUR', 'start': 1760, 'end': 1762, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Hunter', 'start': 2044, 'end': 2049, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}]
#
# Article ID: EN_UA_020543.txt
# Article Content (First 100 chars): Israel turns down Zelensky request to make solidarity visit; 'it's not the right time'
#
#  Ukrainian
# Annotations: [{'entity': 'Israel', 'start': 209, 'end': 214, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Ukraine', 'start': 536, 'end': 542, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Russia', 'start': 571, 'end': 576, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Israel', 'start': 940, 'end': 945, 'main_role': 'Innocent', 'fine_roles': ['Victim']}]
#
# Article ID: EN_UA_001052.txt
# Article Content (First 100 chars): NATO ‘Cautiously Optimistic’ Amid Reports of Russian Troop Withdrawal
#
#  After Russia announced Tues
# Annotations: [{'entity': 'German Chancellor Olaf Scholz', 'start': 2076, 'end': 2104, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'Blinken', 'start': 2945, 'end': 2951, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}]
#
# Article ID: EN_UA_004209.txt
# Article Content (First 100 chars): Russia threatens nukes for US, UK, Finland if NATO expands
#
#  Russia threatens nukes for US, UK, Fin
# Annotations: [{'entity': 'Russia', 'start': 62, 'end': 67, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'NATO', 'start': 108, 'end': 111, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Vladimir Putin', 'start': 122, 'end': 135, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Finland', 'start': 1088, 'end': 1094, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': 'Russia', 'start': 2571, 'end': 2576, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Minister Alexander Grushko', 'start': 3053, 'end': 3078, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'NATO', 'start': 3103, 'end': 3106, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_003579.txt
# Article Content (First 100 chars): International agencies call for urgent aid to address food insecurity
#
#  The Russian invasion of Ukr
# Annotations: [{'entity': 'international organizations', 'start': 306, 'end': 332, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'IMF', 'start': 846, 'end': 848, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'World Bank', 'start': 851, 'end': 860, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'World Trade Organization', 'start': 863, 'end': 886, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'UN World Food Program', 'start': 892, 'end': 912, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'World Bank', 'start': 2714, 'end': 2723, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}]
#
# Article ID: EN_UA_021918.txt
# Article Content (First 100 chars): US, China, Israel and others are developing AI killer drones; this poses significant risks
#
#  by Rho
# Annotations: [{'entity': 'China’s Liberation Army', 'start': 1593, 'end': 1615, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_027879.txt
# Article Content (First 100 chars): Putin Says West Prepared To Scapegoat Zelensky For War Failures: 'Replaced By Next Year'
#
#  Putin Sa
# Annotations: [{'entity': 'West', 'start': 103, 'end': 106, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Vladimir Putin', 'start': 200, 'end': 213, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'the West', 'start': 383, 'end': 390, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Washington', 'start': 857, 'end': 866, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Zelensky', 'start': 1902, 'end': 1909, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Putin', 'start': 2046, 'end': 2050, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Russia', 'start': 2172, 'end': 2177, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_004343.txt
# Article Content (First 100 chars): 14/05/2022 Ukrainians show strength at Deaflympics in Brazil
#
#  Ukrainians show strength at Deaflymp
# Annotations: [{'entity': 'Ukraine', 'start': 883, 'end': 889, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Ukraine', 'start': 1187, 'end': 1193, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}]
#
# Article ID: EN_UA_026740.txt
# Article Content (First 100 chars): Israel to respond to genocide charges at UN’s top court06:35
#
#  Israel to respond to genocide charge
# Annotations: [{'entity': 'Israel', 'start': 64, 'end': 69, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Israel', 'start': 121, 'end': 126, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'South Africa', 'start': 213, 'end': 224, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'Palestinians', 'start': 960, 'end': 971, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'ICJ', 'start': 1686, 'end': 1688, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_008072.txt
# Article Content (First 100 chars): Putin Mobilizes More Troops, Hints at Nuclear Weapon Use in Conflict Over Ukraine
#
#  Russian Preside
# Annotations: [{'entity': 'Putin', 'start': 2431, 'end': 2435, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_100688.txt
# Article Content (First 100 chars): Video shows brave Ukrainian vehicle take on more powerful Russian tank and WIN – as Putin has now lo
# Annotations: [{'entity': 'Kremlin', 'start': 1842, 'end': 1848, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Russia', 'start': 2091, 'end': 2096, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Ukrainians', 'start': 2887, 'end': 2896, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Vladimir Putin', 'start': 4045, 'end': 4058, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_029155.txt
# Article Content (First 100 chars): Head of German Intelligence Reveals Zelensky Behind Nord Stream Pipeline Attack
#
#  The former head o
# Annotations: [{'entity': 'Volodymyr Zelensky', 'start': 160, 'end': 177, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Conspirator']}, {'entity': 'President of Poland', 'start': 183, 'end': 201, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Conspirator']}, {'entity': 'Russia', 'start': 644, 'end': 649, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}, {'entity': 'US', 'start': 2376, 'end': 2377, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'US Navy', 'start': 2485, 'end': 2491, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}]
#
# Article ID: EN_UA_001032.txt
# Article Content (First 100 chars): Russia-Ukraine war map: Where are Russian troops positioned around Ukraine?
#
#  RUSSIA is demanding t
# Annotations: [{'entity': 'Russia', 'start': 2064, 'end': 2069, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Ukraine?', 'start': 2079, 'end': 2086, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Joe Biden', 'start': 2609, 'end': 2617, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Boris Johnson', 'start': 2623, 'end': 2635, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_CC_100066.txt
# Article Content (First 100 chars): Oil companies are killing the planet. Now they want to sell us a fake solution?
#
#  Letters to the Ed
# Annotations: [{'entity': 'California Resources Corp', 'start': 1475, 'end': 1499, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_103995.txt
# Article Content (First 100 chars): Sam Menassa
#
#  Hezbollah recently released a video depicting a military facility in which vehicles l
# Annotations: [{'entity': 'Benjamin Netanyahu', 'start': 617, 'end': 634, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Yahya al-Sinwar', 'start': 2841, 'end': 2855, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_017831.txt
# Article Content (First 100 chars): Pence calls viral clip suggesting he cares more about Ukraine than US ‘fake news’
#
#  Former Vice Pre
# Annotations: [{'entity': 'Mike Pence', 'start': 107, 'end': 116, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': 'Biden administration', 'start': 499, 'end': 518, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Ukraine', 'start': 531, 'end': 537, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'United States', 'start': 829, 'end': 841, 'main_role': 'Innocent', 'fine_roles': ['Forgotten']}, {'entity': 'America', 'start': 1742, 'end': 1748, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Vladimir Putin', 'start': 3056, 'end': 3069, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_021310.txt
# Article Content (First 100 chars): Asia & Pacific Indonesia hosts ASEAN defence chiefs amid multiple crises
#
#  The annual get-together,
# Annotations: [{'entity': 'China', 'start': 259, 'end': 263, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Philippines', 'start': 308, 'end': 318, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'US', 'start': 331, 'end': 332, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'China', 'start': 1716, 'end': 1720, 'main_role': 'Antagonist', 'fine_roles': ['Spy']}, {'entity': 'Russia', 'start': 2144, 'end': 2149, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'China', 'start': 2155, 'end': 2159, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'North Korea', 'start': 2274, 'end': 2284, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}]
#
# Article ID: EN_UA_016012.txt
# Article Content (First 100 chars): Zinchenko recalls heartbreaking moment wife sobbed as Russia invaded Ukraine as Arsenal star says he
# Annotations: [{'entity': 'Russia', 'start': 188, 'end': 193, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Ukraine', 'start': 234, 'end': 240, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Vladimir Putin', 'start': 393, 'end': 406, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Zinchenko', 'start': 1339, 'end': 1347, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Wladimir Klitschko', 'start': 1442, 'end': 1459, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Oleksandr Usyk', 'start': 1462, 'end': 1475, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Vasyl Lomachenko', 'start': 1481, 'end': 1496, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}]
#
# Article ID: EN_UA_104434.txt
# Article Content (First 100 chars): How Putin has amassed a staggering SIX THOUSAND nuclear weapons that could reach UK in 20 minutes
#
#
# Annotations: [{'entity': 'Putin', 'start': 257, 'end': 261, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_014829.txt
# Article Content (First 100 chars): Why the Media Don’t Want to Know the Truth About the Nord Stream Blasts
#
#  by Jonathan Cook, The Unz
# ...
#
# I
# Annotations: [{'entity': 'the Fed', 'start': 608, 'end': 614, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'the Fed', 'start': 1081, 'end': 1087, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_103517.txt
# Article Content (First 100 chars): Evan Gershkovich has jail appeal in Russia blocked as Putin holds innocent WSJ reporter on trumped u
# Annotations: [{'entity': 'Gershkovich', 'start': 636, 'end': 646, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': 'Putin', 'start': 1742, 'end': 1746, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_CC_100123.txt
# Article Content (First 100 chars): 'Entirely Fictional, Shameless': Top Mosquito Expert Blasts Dame Jenny Harries’s Claim That Climate
# Annotations: [{'entity': 'Professor Harries', 'start': 471, 'end': 487, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}, {'entity': 'Paul Reiter', 'start': 862, 'end': 872, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_103025.txt
# Article Content (First 100 chars): ‘This Is A F**king War’: Jamie Dimon Slams Biden For Begging Saudis For Oil
#
#  Three days after Jami
# Annotations: [{'entity': 'Joe Biden', 'start': 2437, 'end': 2445, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'EU', 'start': 2761, 'end': 2762, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_010091.txt
# Article Content (First 100 chars): European leader calls on world, China to pressure Russia
#
#  NUSA DUA – The European Council presiden
# Annotations: [{'entity': 'Russia', 'start': 155, 'end': 160, 'main_role': 'Antagonist', 'fine_roles': ['Instigator', 'Foreign Adversary']}, {'entity': 'Ukraine', 'start': 183, 'end': 189, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Kremlin', 'start': 930, 'end': 936, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Europe', 'start': 1015, 'end': 1020, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Ukraine', 'start': 1055, 'end': 1061, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}]
#
# Article ID: EN_UA_100210.txt
# Article Content (First 100 chars): Russia – Exposure of ‘dirty bomb’ plans caused panic in Kiev
#
#  Russia – Exposure of ‘dirty bomb’ pl
# Annotations: [{'entity': 'Kiev', 'start': 602, 'end': 605, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_UA_100864.txt
# Article Content (First 100 chars): Zelensky Seeks To Cancel Russia At UN, Asks Why "Russian Terrorists" Have A Place
#
#  Zelensky Seeks
# Annotations: [{'entity': 'Russia', 'start': 1502, 'end': 1507, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Putin', 'start': 1799, 'end': 1803, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}, {'entity': 'Russia', 'start': 2079, 'end': 2084, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_CC_200021.txt
# Article Content (First 100 chars): NYC to begin tracking food purchases to make sure residents don’t consume “too much” meat
#
#
# Just as
# Annotations: [{'entity': 'New York City Mayor Eric Adams', 'start': 120, 'end': 149, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Adams', 'start': 679, 'end': 683, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Adams', 'start': 3313, 'end': 3317, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Melissa McKendree', 'start': 3451, 'end': 3467, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}]
#
# Article ID: EN_UA_028520.txt
# Article Content (First 100 chars): EU’s top diplomat angry at Hungarian FM for labeling EU ‘pro-war’
#
#  Josep Borrell, the EU’s High Re
# Annotations: [{'entity': 'The European Union', 'start': 311, 'end': 328, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker', 'Virtuous']}, {'entity': 'Ukraine', 'start': 448, 'end': 454, 'main_role': 'Protagonist', 'fine_roles': ['Rebel', 'Underdog']}, {'entity': 'Viktor Orbán', 'start': 656, 'end': 667, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}]
#
# Article ID: EN_UA_100601.txt
# Article Content (First 100 chars): Australian Open bans flags from Russia and Belarus on site
#
#  Australian Open bans flags from Russia
# Annotations: [{'entity': 'Russia', 'start': 2008, 'end': 2013, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Belarus', 'start': 2039, 'end': 2045, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}]
#
# Article ID: EN_CC_100050.txt
# Article Content (First 100 chars): United Nations COP28 ‘Climate’ Summit Takes Aim at American Farmers, Says Rancher
#
#  United Nations
# Annotations: [{'entity': 'United Nations', 'start': 206, 'end': 219, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}]
#
# Article ID: EN_CC_100003.txt
# Article Content (First 100 chars): Fonda Heads To Canada For Oil Sands Protest, Manages To Tick Everyone Off
#
#  Actress Jane Fonda’s la
# Annotations: [{'entity': 'Justin Trudeau', 'start': 473, 'end': 486, 'main_role': 'Antagonist', 'fine_roles': ['Traitor']}, {'entity': 'Fonda', 'start': 1391, 'end': 1395, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}]
#
# Article ID: EN_UA_100411.txt
# Article Content (First 100 chars): Ukraine: You Break It, We Take It
#
#  Ukraine: You Break It, We Take It
#
# Authored by Citizen Soldier
# Annotations: [{'entity': 'Coalition Provisional Authority', 'start': 1395, 'end': 1425, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'Blinken', 'start': 2890, 'end': 2896, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_UA_021872.txt
# Article Content (First 100 chars): Kremlin warns of tensions if Poland sends troops to monitor Finnish-Russian border
#
#  If Finland dec
# Annotations: [{'entity': 'Finland', 'start': 89, 'end': 95, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Poland', 'start': 235, 'end': 240, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_021123.txt
# Article Content (First 100 chars): CIA's Burns & SecDef Austin In Separate 'Urgent' Trips To Ukraine As War Effort Implodes
#
#  CIA's Bu
# Annotations: [{'entity': 'United States', 'start': 558, 'end': 570, 'main_role': 'Protagonist', 'fine_roles': ['Martyr']}, {'entity': 'Russian', 'start': 2562, 'end': 2568, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}]
#
# Article ID: EN_UA_012234.txt
# Article Content (First 100 chars): Putin’s allies call for London to be ‘turned to dust’ after Ukraine said it would use Brit missiles
# Annotations: [{'entity': 'KREMLIN propagandists', 'start': 119, 'end': 139, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Solovyov', 'start': 556, 'end': 563, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}]
#
# Article ID: EN_UA_010909.txt
# Article Content (First 100 chars): The Downing of Malaysian Airlines MH17: The Quest for Truth and Justice. Review of the Evidence
#
#  b
# Annotations: [{'entity': 'Ukraine’s intelligence agency', 'start': 1042, 'end': 1070, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'John Kerry', 'start': 1853, 'end': 1862, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Samantha Power', 'start': 1892, 'end': 1905, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Moscow', 'start': 1931, 'end': 1936, 'main_role': 'Innocent', 'fine_roles': ['Scapegoat']}]
#
# Article ID: EN_UA_021263.txt
# Article Content (First 100 chars): Fetterman drapes himself in Israeli flag during DC rally in support of the Jewish state
#
#  Fetterman
# Annotations: [{'entity': 'Fetterman', 'start': 573, 'end': 581, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Hamas', 'start': 1865, 'end': 1869, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Israel', 'start': 2059, 'end': 2064, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Ukraine', 'start': 2473, 'end': 2479, 'main_role': 'Innocent', 'fine_roles': ['Victim']}]
#
# Article ID: EN_CC_100012.txt
# Article Content (First 100 chars): WEF Memo Reveals Plan to Depopulate the World of 1 Billion White People By 2030
#
#  The World Economi
# Annotations: [{'entity': 'World Economic Forum', 'start': 87, 'end': 106, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'the United Nations', 'start': 691, 'end': 708, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Dr. Carol Baker', 'start': 1775, 'end': 1789, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Bill Gates-', 'start': 2228, 'end': 2238, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Biden', 'start': 3520, 'end': 3524, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt', 'Traitor']}, {'entity': 'Robert F. Kennedy', 'start': 4416, 'end': 4432, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_013727.txt
# Article Content (First 100 chars): How the U.S. can fight in Ukraine without leading to nuclear war
#
#  Letters to the Editor: How the U
# Annotations: [{'entity': 'U.S', 'start': 99, 'end': 101, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}, {'entity': 'Vladimir Putin', 'start': 473, 'end': 486, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'U.S', 'start': 1208, 'end': 1210, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'NATO', 'start': 1217, 'end': 1220, 'main_role': 'Antagonist', 'fine_roles': ['Corrupt']}, {'entity': 'U.S', 'start': 1438, 'end': 1440, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'NATO', 'start': 1447, 'end': 1450, 'main_role': 'Antagonist', 'fine_roles': ['Tyrant']}, {'entity': 'Ukraine', 'start': 1670, 'end': 1676, 'main_role': 'Innocent', 'fine_roles': ['Victim']}]
#
# Article ID: EN_UA_012803.txt
# Article Content (First 100 chars): Panicking Putin desperately classifies medical files that revealed his ‘cancer battle’ as weak ruler
# Annotations: [{'entity': 'Putin', 'start': 124, 'end': 128, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'Vladimir Putin', 'start': 246, 'end': 259, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Russian government', 'start': 1828, 'end': 1845, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Kremlin', 'start': 2104, 'end': 2110, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_CC_200016.txt
# Article Content (First 100 chars): Climate change protesters hoping to ‘shut down’ Congressional Baseball Game
#
#
# Climate change protes
# Annotations: [{'entity': 'Climate Defiance', 'start': 216, 'end': 231, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur', 'Conspirator']}, {'entity': 'Far Left', 'start': 832, 'end': 839, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'DemonRAT', 'start': 842, 'end': 849, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Red Flag', 'start': 852, 'end': 859, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'No Sale Gun', 'start': 862, 'end': 872, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}]
#
# Article ID: EN_UA_104523.txt
# Article Content (First 100 chars): The Lies that All Pro-U.S.-Government Media Spread
#
#  by Eric Zuesse, The Duran:
#
# First here, are a
# Annotations: [{'entity': 'America’s', 'start': 3166, 'end': 3174, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary']}]
#
# Article ID: EN_UA_011260.txt
# Article Content (First 100 chars): Russia has a clear plan to resolve the conflict in Ukraine
#
#  The conflict in Ukraine may end either
# Annotations: [{'entity': 'Ukraine', 'start': 263, 'end': 269, 'main_role': 'Antagonist', 'fine_roles': ['Foreign Adversary', 'Tyrant']}, {'entity': 'Russia', 'start': 637, 'end': 642, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'Ukrainian leadership', 'start': 830, 'end': 849, 'main_role': 'Antagonist', 'fine_roles': ['Instigator', 'Tyrant']}, {'entity': 'Kyiv regime', 'start': 958, 'end': 968, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'European Union', 'start': 1075, 'end': 1088, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Ukraine', 'start': 1225, 'end': 1231, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Ukrainian people', 'start': 1387, 'end': 1402, 'main_role': 'Innocent', 'fine_roles': ['Victim']}]
#
# Article ID: EN_CC_100124.txt
# Article Content (First 100 chars): Glaciers Give the Lie to Global Warming Narrative
#
#  Glaciers Give the Lie to Global Warming Narrati
# Annotations: [{'entity': 'Michael Mann', 'start': 586, 'end': 597, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}, {'entity': 'Al Gore', 'start': 660, 'end': 666, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}]
#
# Article ID: EN_CC_100002.txt
# Article Content (First 100 chars): Oxford Residents Mount Resistance Against the Sectioning of Their Streets
#
#  OXFORD RESIDENTS MOUNT
# Annotations: [{'entity': 'Piers Corbyn', 'start': 809, 'end': 820, 'main_role': 'Protagonist', 'fine_roles': ['Rebel']}]
#
# Article ID: EN_CC_200022.txt
# Article Content (First 100 chars): Denmark to Punish Farmers for Cow ‘Emissions’ to ‘Fight Global Warming’
#
#  by Frank Bergman, Slay Ne
# Annotations: [{'entity': 'World Economic Forum', 'start': 408, 'end': 427, 'main_role': 'Antagonist', 'fine_roles': ['Conspirator']}, {'entity': 'Denmark', 'start': 585, 'end': 591, 'main_role': 'Antagonist', 'fine_roles': ['Bigot']}, {'entity': 'United Nations Environment Program', 'start': 2289, 'end': 2322, 'main_role': 'Antagonist', 'fine_roles': ['Deceiver']}]
#
# Article ID: EN_UA_013257.txt
# Article Content (First 100 chars): Putin says what Russia needs to do to win special operation in Ukraine
#
#  Russia will win the specia
# Annotations: [{'entity': 'Russia', 'start': 375, 'end': 380, 'main_role': 'Protagonist', 'fine_roles': ['Underdog']}, {'entity': 'Russia', 'start': 944, 'end': 949, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Russia', 'start': 1590, 'end': 1595, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Western countries', 'start': 1667, 'end': 1683, 'main_role': 'Antagonist', 'fine_roles': ['Saboteur']}, {'entity': 'Russia', 'start': 1763, 'end': 1768, 'main_role': 'Protagonist', 'fine_roles': ['Virtuous']}]
#
# Article ID: EN_UA_000104.txt
# Article Content (First 100 chars): Senate blocks sanctions aimed at stopping Nord Stream 2 pipeline
#
#  The Senate blocked a measure to
# Annotations: [{'entity': 'Biden administration', 'start': 188, 'end': 207, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Russia', 'start': 513, 'end': 518, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Ukraine', 'start': 890, 'end': 896, 'main_role': 'Innocent', 'fine_roles': ['Victim']}, {'entity': 'Biden administration', 'start': 1210, 'end': 1229, 'main_role': 'Protagonist', 'fine_roles': ['Peacemaker']}, {'entity': 'government of Germany', 'start': 2223, 'end': 2243, 'main_role': 'Antagonist', 'fine_roles': ['Incompetent']}, {'entity': 'McConnell', 'start': 2512, 'end': 2520, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}]
#
# Article ID: EN_UA_027787.txt
# Article Content (First 100 chars): Russia Says US Is Responsible for Deadly Ukrainian Attack on Crimea
#
#  MOSCOW—Russia said on Sunday
# Annotations: [{'entity': 'the United States', 'start': 105, 'end': 121, 'main_role': 'Antagonist', 'fine_roles': ['Instigator']}, {'entity': 'Kremlin', 'start': 1864, 'end': 1870, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'Dmitry Medvedev', 'start': 1970, 'end': 1984, 'main_role': 'Protagonist', 'fine_roles': ['Guardian']}, {'entity': 'U.S. administration', 'start': 2269, 'end': 2287, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}, {'entity': 'Ukrainian leaders', 'start': 2290, 'end': 2306, 'main_role': 'Antagonist', 'fine_roles': ['Terrorist']}]

# %%
predictions = predict_for_multiple_articles(model, articles_annotations, window_size=50)

# Assuming `all_annotations` is a list of annotations for all articles
# Pass the annotations correctly by extracting them from the values
annotations_list = [ann for _, ann in articles_annotations.values()]
emr = exact_match_ratio_for_multiple_articles(predictions, annotations_list)

print(f"Exact Match Ratio: {emr:.2f}")

# Print predictions
for article_pred in predictions:
    print(f"Article ID: {article_pred['article_id']}")
    for pred in article_pred['predictions']:
        entity = pred["entity"]
        main_role = pred["main_role"]
        fine_roles = pred["fine_roles"]

        print(f"Entity: {entity}")
        print(f"  Main Role: {main_role}")
        print(f"  Fine-Grained Roles: {', '.join(fine_roles)}\n")
# Out:
# Fine-Grained Role Probabilities: [0.183330237865448, 0.07235962897539139, 0.08065172284841537, 0.0251990407705307, 0.09104344248771667, 0.10315995663404465, 0.18548066914081573, 0.15528427064418793, 0.11860454082489014, 0.020167149603366852, 0.021038053557276726, 0.04313741251826286, 0.10087250173091888, 0.02429286576807499, 0.025104478001594543, 0.07179445773363113, 0.019222889095544815, 0.018534621223807335, 0.03038029558956623, 0.05343528091907501, 0.15256908535957336, 0.062432911247015]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.18315614759922028, 0.07215557992458344, 0.08047887682914734, 0.025095462799072266, 0.09083646535873413, 0.1029348224401474, 0.1852513998746872, 0.15512752532958984, 0.11837158352136612, 0.020083937793970108, 0.020959632471203804, 0.042984116822481155, 0.10067393630743027, 0.024203697219491005, 0.02501627244055271, 0.07159428298473358, 0.019151344895362854, 0.018467403948307037, 0.030265703797340393, 0.05326732248067856, 0.152242511510849, 0.06225895509123802]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.18358199298381805, 0.07248850166797638, 0.08084078133106232, 0.02529505081474781, 0.0912901982665062, 0.10333453863859177, 0.18572869896888733, 0.1555020809173584, 0.11881045997142792, 0.020235314965248108, 0.021095192059874535, 0.04325804486870766, 0.10103089362382889, 0.024364953860640526, 0.025186363607645035, 0.07197042554616928, 0.019290365278720856, 0.018591783940792084, 0.030474092811346054, 0.05358109250664711, 0.15279901027679443, 0.06259649991989136]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.18343284726142883, 0.07235857099294662, 0.08070831000804901, 0.025221187621355057, 0.09113431721925735, 0.1031607910990715, 0.18551087379455566, 0.15537048876285553, 0.1186211109161377, 0.020178096368908882, 0.021034326404333115, 0.043171416968107224, 0.10090968012809753, 0.024309372529387474, 0.02512390911579132, 0.07182349264621735, 0.019226836040616035, 0.018542984500527382, 0.030403578653931618, 0.05345601215958595, 0.15259864926338196, 0.06247565522789955]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Paul Reiter
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_103025.txt
# Entity: Joe Biden
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: EU
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_010091.txt
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Kremlin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Europe
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_100210.txt
# Entity: Kiev
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_100864.txt
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Putin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_200021.txt
# Entity: New York City Mayor Eric Adams
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Adams
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Adams
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Melissa McKendree
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_028520.txt
# Entity: The European Union
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Viktor Orbán
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_100601.txt
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Belarus
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_100050.txt
# Entity: United Nations
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_100003.txt
# Entity: Justin Trudeau
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Fonda
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_100411.txt
# Entity: Coalition Provisional Authority
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Blinken
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_021872.txt
# Entity: Finland
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Poland
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_021123.txt
# Entity: United States
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russian
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_012234.txt
# Entity: KREMLIN propagandists
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Solovyov
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_010909.txt
# Entity: Ukraine’s intelligence agency
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: John Kerry
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Samantha Power
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Moscow
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_021263.txt
# Entity: Fetterman
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Hamas
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Israel
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_100012.txt
# Entity: World Economic Forum
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: the United Nations
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Dr. Carol Baker
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Bill Gates-
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Biden
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Robert F. Kennedy
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_013727.txt
# Entity: U.S
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Vladimir Putin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: U.S
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: NATO
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: U.S
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: NATO
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_012803.txt
# Entity: Putin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Vladimir Putin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russian government
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Kremlin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_200016.txt
# Entity: Climate Defiance
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Far Left
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: DemonRAT
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Red Flag
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: No Sale Gun
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_104523.txt
# Entity: America’s
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_011260.txt
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukrainian leadership
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Kyiv regime
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: European Union
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukrainian people
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_100124.txt
# Entity: Michael Mann
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Al Gore
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_100002.txt
# Entity: Piers Corbyn
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_CC_200022.txt
# Entity: World Economic Forum
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Denmark
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: United Nations Environment Program
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_013257.txt
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Western countries
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_000104.txt
# Entity: Biden administration
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Russia
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukraine
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Biden administration
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: government of Germany
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: McConnell
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Article ID: EN_UA_027787.txt
# Entity: the United States
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Kremlin
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Dmitry Medvedev
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: U.S. administration
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator
#
# Entity: Ukrainian leaders
#   Main Role: Antagonist
#   Fine-Grained Roles: Instigator, Conspirator

# %%
import os
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, jaccard_score

# Function to load an article given its ID and folder path
def load_article(article_id, lang_folder):
    article_path = os.path.join(lang_folder, f"{article_id}")
    with open(article_path, 'r', encoding='utf-8') as f:
        article = f.read()
    return article

# Function to load all annotations from the annotation file
def load_all_annotations(annotation_file):
    annotations_dict = {}
    with open(annotation_file, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split('\t')
            article_id = parts[0]
            annotation = {
                'entity': parts[1],
                'start': int(parts[2]),
                'end': int(parts[3]),
                'main_role': parts[4],
                'fine_roles': parts[5:]
            }
            if article_id not in annotations_dict:
                annotations_dict[article_id] = []
            annotations_dict[article_id].append(annotation)
    return annotations_dict

# Function to create the articles_annotations dictionary
def load_articles_annotations(lang_folder, annotation_file):
    articles_annotations = {}
    annotations_dict = load_all_annotations(annotation_file)
    for article_id in annotations_dict.keys():
        article_text = load_article(article_id, lang_folder)
        annotations = annotations_dict[article_id]
        articles_annotations[article_id] = (article_text, annotations)
    return articles_annotations

# Load articles and their annotations
lang_folder = "EN/raw-documents"
annotation_file = "EN/annotations/subtask-1-annotations.txt"
articles_annotations = load_articles_annotations(lang_folder, annotation_file)

# Example prediction function (replace with your actual model prediction logic)
predictions = predict_for_multiple_articles(model, articles_annotations, window_size=50)

# Extract ground truth annotations for evaluation
def extract_labels(annotations):
    entities_labels = []
    for annotation in annotations:
        entity = annotation['entity']
        fine_roles = annotation['fine_roles']
        entities_labels.append((entity, fine_roles))
    return entities_labels

# Flatten predictions and true labels for evaluation
true_labels = []
pred_labels = []

for article_pred in predictions:
    article_id = article_pred['article_id']
    predicted_entities = article_pred['predictions']
    true_annotations = articles_annotations[article_id][1]

    # Extract true and predicted roles for comparison
    true_entities = extract_labels(true_annotations)
    for pred in predicted_entities:
        entity = pred["entity"]
        fine_roles_pred = pred["fine_roles"]

        # Find corresponding true roles
        matching_true = next((t for t in true_entities if t[0] == entity), None)
        fine_roles_true = matching_true[1] if matching_true else []

        # Store the roles for comparison
        true_labels.append(fine_roles_true)
        pred_labels.append(fine_roles_pred)

# Convert roles into binary vectors for multi-label comparison
mlb = MultiLabelBinarizer()
true_binary = mlb.fit_transform(true_labels)
pred_binary = mlb.transform(pred_labels)

# Evaluation metrics function
def evaluate_metrics(true_binary, pred_binary):
    accuracy = accuracy_score(true_binary, pred_binary)
    precision = precision_score(true_binary, pred_binary, average='weighted', zero_division=0)
    recall = recall_score(true_binary, pred_binary, average='weighted', zero_division=0)
    f1 = f1_score(true_binary, pred_binary, average='weighted', zero_division=0)
    jaccard = jaccard_score(true_binary, pred_binary, average='samples', zero_division=0)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Jaccard Similarity: {jaccard:.4f}")

# Run the evaluation
evaluate_metrics(true_binary, pred_binary)
# Out:
# Fine-Grained Role Probabilities: [0.183330237865448, 0.07235962897539139, 0.08065172284841537, 0.0251990407705307, 0.09104344248771667, 0.10315995663404465, 0.18548066914081573, 0.15528427064418793, 0.11860454082489014, 0.020167149603366852, 0.021038053557276726, 0.04313741251826286, 0.10087250173091888, 0.02429286576807499, 0.025104478001594543, 0.07179445773363113, 0.019222889095544815, 0.018534621223807335, 0.03038029558956623, 0.05343528091907501, 0.15256908535957336, 0.062432911247015]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.18315614759922028, 0.07215557992458344, 0.08047887682914734, 0.025095462799072266, 0.09083646535873413, 0.1029348224401474, 0.1852513998746872, 0.15512752532958984, 0.11837158352136612, 0.020083937793970108, 0.020959632471203804, 0.042984116822481155, 0.10067393630743027, 0.024203697219491005, 0.02501627244055271, 0.07159428298473358, 0.019151344895362854, 0.018467403948307037, 0.030265703797340393, 0.05326732248067856, 0.152242511510849, 0.06225895509123802]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.18358199298381805, 0.07248850166797638, 0.08084078133106232, 0.02529505081474781, 0.0912901982665062, 0.10333453863859177, 0.18572869896888733, 0.1555020809173584, 0.11881045997142792, 0.020235314965248108, 0.021095192059874535, 0.04325804486870766, 0.10103089362382889, 0.024364953860640526, 0.025186363607645035, 0.07197042554616928, 0.019290365278720856, 0.018591783940792084, 0.030474092811346054, 0.05358109250664711, 0.15279901027679443, 0.06259649991989136]
# Valid Roles for Antagonist: ['Conspirator', 'Spy', 'Terrorist', 'Instigator', 'Tyrant', 'Saboteur']
# Predicted Fine Roles: ['Guardian', 'Instigator', 'Conspirator', 'Victim']
# Fine-Grained Role Probabilities: [0.